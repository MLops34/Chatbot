# %%
# !pip install -q \
streamlit \
PyPDF2 \
langchain \
langchain-community \
langchain-core \
langchain-openai \
faiss-cpu \
sentence-transformers \
huggingface-hub \
python-dotenv \
pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 88.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 102.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
# !pip install -q requests==2.32.4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.1 requires requests<3.0.0,>=2.32.5, but you have requests 2.32.4 which is incompatible.

# %%
import os
os.environ["OPENAI_API_KEY"] = "API_KEY"

# %%
print(os.getenv("OPENAI_API_KEY") is not None)
# Out:
# True

# %%
# !ls
# Out:
# Ex5.py	rag_pdf.py  sample_data

# %%
from pyngrok import ngrok
ngrok.set_auth_token("Yours")

# %%
pip install ctransformers --no-binary ctransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.1/376.1 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ctransformers: filename=ctransformers-0.2.27-cp312-cp312-linux_x86_64.whl size=596119 sha256=e278484f71d2482271d7e037d52018294c143ea2e0d4edcc17dc21e2f6d527e0
#   Stored in directory: /root/.cache/pip/wheels/ae/c8/23/7fe0a2311fba0a036b16e62863f867984970290b7e62d9fb21
# Successfully built ctransformers
# ...

# %%
pip install huggingface-hub

# %%
from pyngrok import ngrok
ngrok.kill()

public_url = ngrok.connect(8501)
print("🌍 Streamlit URL:", public_url)
# Out:
# 🌍 Streamlit URL: NgrokTunnel: "https://nonrateable-polyrhythmically-robt.ngrok-free.dev" -> "http://localhost:8501"

# %%
# run this cell once, wait until the progress bar finishes
# !mkdir -p ~/.cache/ctransformers
# !wget -q --show-progress -O ~/.cache/ctransformers/llama-2-7b-chat.ggmlv3.q4_0.bin \
     https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGML/resolve/main/llama-2-7b-chat.ggmlv3.q4_0.bin
# Out:
# /root/.cache/ctrans 100%[===================>]   3.53G  13.1MB/s    in 4m 54s

# %%
# !ls -lh ~/.cache/ctransformers/
# you must see 3.0 G … llama-2-7b-chat.ggmlv3.q4_0.bin
# Out:
# total 3.6G
# -rw-r--r-- 1 root root 3.6G Jan 10 14:11 llama-2-7b-chat.ggmlv3.q4_0.bin

# %%
# !streamlit run Ex5.py \
  --server.port 8501 \
  --server.enableCORS false \
  --server.enableXsrfProtection false
# Out:
# ...
# WARNING:pyngrok.process.ngrok:t=2026-01-13T07:32:07+0000 lvl=warn msg="failed to open private leg" id=38014de7759a privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-01-13T07:32:07+0000 lvl=warn msg="failed to open private leg" id=f87a053e1798 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.240.149.226:8501
#
# 2026-01-13 07:32:20.126434: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-13 07:32:20.133420: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
# !./cloudflared-linux-amd64 tunnel --url http://localhost:8501
